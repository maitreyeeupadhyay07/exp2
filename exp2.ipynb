# %%
# MAITREYEE UPADHYAY PRN: 25070123071
# EXP 2 : STUDY OF LIST IN PYTHON
list1=["apple","banana","orange"]
print(list1)
# Out:
# ['apple', 'banana', 'orange']

# %%
list2=[2,2.3,"maitreyee",True]
print(list2)
# Out:
# [2, 2.3, 'maitreyee', True]

# %%
list3=["apple","orange","apple","cherry"]
print(list3)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
list4=["apple","banana","orange","cherry","mango","kiwi"]
print(list4[2])
print(list4[-4])
print(list4[2:5])
print(list4[:4])
print(list4[2:])
# Out:
# orange
# orange
# ['orange', 'cherry', 'mango']
# ['apple', 'banana', 'orange', 'cherry']
# ['orange', 'cherry', 'mango', 'kiwi']

# %%
list5=["apple","orange","mango"]
list5[1]=2
print(list5)
# Out:
# ['apple', 2, 'mango']

# %%
list6=["apple","orange","cherry"]
list6.append("mango")
print(list6)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list7=["apple","orange","cherry"]
list7.insert(1,"mango")
print(list7)
# Out:
# ['apple', 'mango', 'orange', 'cherry']

# %%
list8=["apple","orange","cherry"]
list9=["kiwi","mango"]
list8.extend(list9)
print(list8)
print(list9)
# Out:
# ['apple', 'orange', 'cherry', 'kiwi', 'mango']
# ['kiwi', 'mango']

# %%
marks=[90,82,66,76,33]
max_marks=max(marks)
print(max_marks)

min_marks=min(marks)
print(min_marks)

total_numberofstudents=len(marks)
print(total_numberofstudents)

sumofmarks=sum(marks)
print(sumofmarks)

average_marks=sumofmarks/total_numberofstudents
print(average_marks)

marks.sort()
print(marks)
# Out:
# 90
# 33
# 5
# 347
# 69.4
# [33, 66, 76, 82, 90]

# %%
list10=["milk","chocolates","eggs"]
list10.append("mango")
list10.append("vegetables")
print(list10)
list10.remove("eggs")
print(list10)
# Out:
# ['milk', 'chocolates', 'eggs', 'mango', 'vegetables']
# ['milk', 'chocolates', 'mango', 'vegetables']
